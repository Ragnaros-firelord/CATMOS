# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\19189\Desktop\trial1.csv')
df
# Out:
#     number  values_0  values_1              datetime_start  \
# 0        0  0.408058  0.369947  2024-03-09 14:17:41.195501
# 1        1 -0.097059  0.688606  2024-03-09 14:29:27.439236
# 2        2 -0.097211  0.688701  2024-03-09 14:33:27.662630
# 3        3 -0.066839  0.669261  2024-03-09 14:37:07.857832
# 4        4  0.409202  0.371366  2024-03-09 14:40:19.492190
# 5        5 -0.097190  0.688688  2024-03-09 14:49:25.195924
# 6        6 -0.097017  0.688580  2024-03-09 14:53:36.190923
# 7        7 -0.097200  0.688694  2024-03-09 15:10:06.161797
# 8        8  0.102464  0.561709  2024-03-09 15:23:23.906715
# 9        9 -0.095359  0.687527  2024-03-09 15:26:55.424596
# 10      10  0.275180  0.454134  2024-03-09 15:31:01.954365
# 11      11 -0.097184  0.688684  2024-03-09 15:40:08.336484
# 12      12  0.320336  0.425213  2024-03-09 15:56:26.739802
# 13      13 -0.097218  0.688706  2024-03-09 16:01:21.925682
# 14      14  0.486193  0.322443  2024-03-09 16:15:27.491330
# ...

# %%
df_sort=df.sort_values(by='params_eta')
df_sort
# Out:
#     number  values_0  values_1              datetime_start  \
# 29      29 -0.097224  0.688710  2024-03-09 19:20:18.615860
# 32      32 -0.097224  0.688710  2024-03-09 19:55:27.445094
# 28      28 -0.097222  0.688709  2024-03-09 18:59:17.345182
# 47      47 -0.097224  0.688710  2024-03-09 22:13:58.827538
# 2        2 -0.097211  0.688701  2024-03-09 14:33:27.662630
# ..     ...       ...       ...                         ...
# 67      67  0.274326  0.450447  2024-03-10 02:31:11.898455
# 35      35  0.241873  0.471071  2024-03-09 20:35:14.309005
# 90      90  0.468279  0.331545  2024-03-10 08:03:31.281875
# 63      63 -0.208679  0.747326  2024-03-10 01:41:29.348293
# 26      26 -0.089316  0.667238  2024-03-09 18:32:20.903909
#
#              datetime_complete                duration  params_alpha  \
# 29  2024-03-09 19:28:23.459541  0 days 00:08:04.843681  6.132996e-07
# 32  2024-03-09 20:01:06.599347  0 days 00:05:39.154253  1.195172e-03
# ...

# %%
plt.figure(figsize=(8,8))
plt.scatter(df_sort.params_eta.values,df_sort.values_0.values,label='R2')
plt.scatter(df_sort.params_eta.values,df_sort.values_1.values,label='MSE')
plt.legend(loc='upper center')
plt.xscale('log')
plt.show()

# %%
df=df[df['params_eta']>=0.01]
df
# Out:
#     number  values_0  values_1              datetime_start  \
# 0        0  0.408058  0.369947  2024-03-09 14:17:41.195501
# 4        4  0.409202  0.371366  2024-03-09 14:40:19.492190
# 14      14  0.486193  0.322443  2024-03-09 16:15:27.491330
# 22      22  0.395095  0.379781  2024-03-09 18:12:11.015722
# 24      24  0.513867  0.305890  2024-03-09 18:23:01.244683
# 10      10  0.458115  0.339323  2024-03-11 17:00:12.540344
# 11      11  0.204116  0.498371  2024-03-11 17:01:48.181078
# 12      12  0.526620  0.297199  2024-03-11 17:18:30.363268
# 13      13  0.511670  0.306978  2024-03-11 17:30:17.647535
# 14      14  0.479500  0.327164  2024-03-11 17:40:17.244068
# ...

# %%
df_sort=df3.sort_values(by='values_0',ascending=False)
df_sort
# Out:
#     number  values_0  values_1              datetime_start  \
# 26      26  0.539651  0.289118  2024-03-11 19:27:28.941729
# 45      45  0.538650  0.290198  2024-03-11 22:18:21.290520
# 46      46  0.537414  0.291603  2024-03-11 22:31:34.241188
# 6        6  0.530349  0.295519  2024-03-11 16:03:23.635909
# 47      47  0.529851  0.295751  2024-03-11 22:42:49.435371
# 49      49  0.529323  0.296017  2024-03-11 23:09:01.202677
# 41      41  0.528597  0.296445  2024-03-11 21:24:36.254592
# 2        2  0.527117  0.296851  2024-03-11 14:47:13.111030
# 12      12  0.526620  0.297199  2024-03-11 17:18:30.363268
# 37      37  0.525663  0.297592  2024-03-11 20:52:19.841369
# 27      27  0.525242  0.298358  2024-03-11 20:01:18.488880
# 39      39  0.524808  0.298531  2024-03-11 21:10:34.052182
# 32      32  0.524334  0.299741  2024-03-11 20:25:59.667870
# 34      34  0.511676  0.307220  2024-03-11 20:37:43.876623
# 13      13  0.511670  0.306978  2024-03-11 17:30:17.647535
# ...

# %%
d=df3.iloc[0,6:20]
row=d.to_dict()
row
# Out:
# {'params_alpha': 2.087673872717932e-07,
#  'params_booster': 'dart',
#  'params_colsample_bytree': 0.9435146019279936,
#  'params_gamma': 0.0709398199800134,
#  'params_grow_policy': 'lossguide',
#  'params_lambda': 1.3275665587450564e-05,
#  'params_max_depth': 9,
#  'params_min_child_weight': 9,
#  'params_n_estimators': 160,
#  'params_normalize_type': 'tree',
#  'params_rate_drop': 0.1144318947616248,
#  'params_sample_type': 'uniform',
#  'params_skip_drop': 0.0108769135675099,
#  'params_subsample': 0.8321343112217487}

# %%
df=pd.read_csv(r"C:\Users\19189\Desktop\mordred_descriptors.csv")
df
# Out:
#             CASRN  CATMoS_LD50_mgkg  \
# 0      68523-18-2            460.00
# 1         88-04-0           3830.00
# 2        603-50-9           4305.00
# 3        120-36-5            689.00
# 4        103-26-4           2610.00
# ...           ...               ...
# 11982    996-04-3              1.78
# 11983    996-05-4             18.00
# 11984  99784-08-4           7500.00
# 11985  99874-01-8           5220.00
# 11986    999-34-8              2.24
#
#                                          Canonical_QSARr   LogLD50  ABC  \
# 0      CC1(C)C(C1C=C(Cl)Cl)C(=O)OC(C#N)C1C=CC=C(N=1)O...  2.662758  0.0
# 1                                   CC1C=C(O)C=C(C)C=1Cl  3.583199  0.0
# 2      CC(=O)OC1C=CC(=CC=1)C(C1C=CC=CN=1)C1C=CC(=CC=1...  3.633973  0.0
# 3                           CC(OC1C=CC(Cl)=CC=1Cl)C(O)=O  2.838219  0.0
# 4                                  COC(=O)C=CC1C=CC=CC=1  3.416641  0.0
# ...                                                  ...       ...  ...
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform, randint
from sklearn.datasets import load_breast_cancer, load_diabetes, load_wine
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, StratifiedKFold, RandomizedSearchCV, train_test_split
import xgboost as xgb

# %%
import graphviz
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error as MSE

# %%
X=df.iloc[:,4:1831]
X = X.astype(float)
y=df.LogLD50.values

# %%
model = xgb.XGBRegressor(**params)
kfold = KFold(n_splits=5)
results = cross_val_score(model, X, y,scoring = "neg_mean_squared_error",cv=kfold)
print(results.mean())

# %%
params1={'alpha': 4.040391386445593e-05,
 'booster': 'dart',
 'colsample_bytree': 0.648064512219035,
 'gamma': 0.0009763486906128,
 'grow_policy': 'depthwise',
 'lambda': 3.405102039996652e-05,
 'max_depth': 9,
 'min_child_weight': 4,
 'n_estimators': 260,
 'normalize_type': 'forest',
 'rate_drop': 0.0034599291068901,
 'sample_type': 'weighted',
 'skip_drop': 0.0096339740817456,
 'subsample': 0.8966075451246887,
 'random_state':42}
#r2=0.539651

# %%
import graphviz
from sklearn.metrics import mean_squared_error as MSE
X=df.iloc[:,4:1831]
X = X.astype(float)
y=df.LogLD50.values
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=42)
xgb_model1 = xgb.XGBRegressor(**params1).fit(X_train, y_train)
y_pred=xgb_model1.predict(X_test)
print(xgb_model1.score(X_test,y_test))
print(MSE(y_test,y_pred))
# Out:
# 0.5279049103251152
# 0.3144914168812446

# %%
params2={'alpha': 2.087673872717932e-07,
 'booster': 'dart',
 'colsample_bytree': 0.9435146019279936,
 'gamma': 0.0709398199800134,
 'grow_policy': 'lossguide',
 'lambda': 1.3275665587450564e-05,
 'max_depth': 9,
 'min_child_weight': 9,
 'n_estimators': 160,
 'normalize_type': 'tree',
 'rate_drop': 0.1144318947616248,
 'sample_type': 'uniform',
 'skip_drop': 0.0108769135675099,
 'subsample': 0.8321343112217487,
 'random_state':42}
#r2=0.436629

# %%
X=df.iloc[:,4:1831]
X = X.astype(float)
y=df.LogLD50.values
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=42)
xgb_model2 = xgb.XGBRegressor(**params2).fit(X_train, y_train)
y_pred=xgb_model2.predict(X_test)
print(xgb_model2.score(X_test,y_test))
print(MSE(y_test,y_pred))
# Out:
# 0.5593670427876933
# 0.29353256593645793

# %%
xgb.plot_importance(xgb_model1, max_num_features=10)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
xgb.plot_importance(xgb_model2, max_num_features=10)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
xgb.to_graphviz(xgb_model)

# %%
xgb.plot_importance(xgb_model, max_num_features=20)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>
