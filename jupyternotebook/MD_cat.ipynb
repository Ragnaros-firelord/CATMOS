# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import uniform, randint

from sklearn.datasets import load_breast_cancer, load_diabetes, load_wine
from sklearn.metrics import auc, accuracy_score, balanced_accuracy_score, confusion_matrix, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, StratifiedKFold, RandomizedSearchCV, train_test_split
import catboost as cat

# %%
df=pd.read_csv(r"C:\Users\19189\Desktop\mordred_descriptors.csv")
df
# Out:
#             CASRN  CATMoS_LD50_mgkg  \
# 0      68523-18-2            460.00
# 1         88-04-0           3830.00
# 2        603-50-9           4305.00
# 3        120-36-5            689.00
# 4        103-26-4           2610.00
# ...           ...               ...
# 11982    996-04-3              1.78
# 11983    996-05-4             18.00
# 11984  99784-08-4           7500.00
# 11985  99874-01-8           5220.00
# 11986    999-34-8              2.24
#
#                                          Canonical_QSARr   LogLD50  ABC  \
# 0      CC1(C)C(C1C=C(Cl)Cl)C(=O)OC(C#N)C1C=CC=C(N=1)O...  2.662758  0.0
# 1                                   CC1C=C(O)C=C(C)C=1Cl  3.583199  0.0
# 2      CC(=O)OC1C=CC(=CC=1)C(C1C=CC=CN=1)C1C=CC(=CC=1...  3.633973  0.0
# 3                           CC(OC1C=CC(Cl)=CC=1Cl)C(O)=O  2.838219  0.0
# 4                                  COC(=O)C=CC1C=CC=CC=1  3.416641  0.0
# ...                                                  ...       ...  ...
# 11982                                   CP(=O)(SCCC)SCCC  0.250420  0.0
# 11983                                   CP(=S)(SCCC)SCCC  1.255273  0.0
# 11984                  COC1C=CC(=CC=1O)C1COC2=CC=CC=C2O1  3.875061  0.0
# 11985                          CC(C)(S)C(=O)NC(CS)C(O)=O  3.717671  0.0
# 11986                                       CP(SCCC)SCCC  0.350248  0.0
#
#        ABCGG  nAcid  nBase    SpAbs_A   SpMax_A  ...      SRW10     TSRW10  \
# 0        0.0      0      0  34.992970  2.613976  ...  10.344674  84.588084
# 1        0.0      0      0  11.643052  2.307250  ...   9.078065  39.748909
# 2        0.0      0      0  34.387058  2.415622  ...  10.045811  61.772145
# 3        0.0      1      0  16.532794  2.301365  ...   9.254262  45.062973
# 4        0.0      0      0  15.354433  2.172565  ...   8.688622  41.277218
# ...      ...    ...    ...        ...       ...  ...        ...        ...
# 11982    0.0      0      0  12.592066  2.188901  ...   8.586906  39.549123
# 11983    0.0      0      0  12.592066  2.188901  ...   8.586906  39.549123
# 11984    0.0      0      0  25.276144  2.403626  ...   9.883948  52.530255
# 11985    0.0      1      0  13.983995  2.272120  ...   9.131838  43.455545
# 11986    0.0      0      0  11.918006  2.028523  ...   7.878155  36.593370
#
#                MW        AMW  WPath  WPol  Zagreb1  Zagreb2   mZagreb1  \
# 0      416.069448   9.044988   2244    39    146.0    172.0  10.201389
# 1      156.034193   8.212326    110    13     48.0     54.0   4.944444
# 2      361.131408   7.850683   1954    39    136.0    155.0   8.638889
# 3      233.985049  10.635684    316    18     66.0     73.0   6.555556
# 4      162.068080   7.366731    226    12     52.0     55.0   4.222222
# ...           ...        ...    ...   ...      ...      ...        ...
# 11982  212.045844   7.573066    180    10     44.0     44.0   5.562500
# 11983  228.023000   8.143679    180    10     44.0     44.0   5.562500
# 11984  258.089209   7.820885    720    30    100.0    118.0   5.416667
# 11985  223.033685   8.578219    256    16     58.0     62.0   7.895833
# 11986  196.050929   7.261146    149     8     36.0     35.0   4.611111
#
#        mZagreb2
# 0      6.166667
# 1      2.222222
# 2      6.000000
# 3      3.138889
# 4      2.916667
# ...         ...
# 11982  2.750000
# 11983  2.750000
# 11984  4.250000
# 11985  2.944444
# 11986  2.666667
#
# [11987 rows x 1830 columns]

# %%
import graphviz
from sklearn.metrics import mean_squared_error as MSE
x=df.iloc[:,4:1831]
x = x.astype(float)
y=df.LogLD50.values

# %%
import optuna
def objective(trial):
    param = {
        'iterations':trial.suggest_int("iterations", 500, 1000, step=100),
        'learning_rate': trial.suggest_float("learning_rate",0.0001, 0.1,log=True),
        'depth':trial.suggest_int("depth", 4, 12, step=2),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-6, 1.0, log=True),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]), 
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]), 
        'random_strength':trial.suggest_float("random_strength", 1e-6, 5.0, log=True),
        'leaf_estimation_method':"Gradient",
        'score_function':trial.suggest_categorical("score_function", ["L2", "Cosine"]),
        'early_stopping_rounds':20,
        'eval_metric':'R2',
        'rsm':trial.suggest_float("rsm", 0.1, 1.0, log=True)
    }
    if param["bootstrap_type"] == "Bayesian": 
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10) 
    elif param["bootstrap_type"] == "Bernoulli": 
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1) 
    
    cat_model = cat.CatBoostRegressor(**param)

    r2 = cross_val_score(cat_model, x, y, n_jobs=-1, cv=5, scoring="r2").mean()
    
    return r2

study = optuna.create_study(
    direction="maximize",
    study_name="catboost_parameter_opt",
    pruner = optuna.pruners.MedianPruner(n_warmup_steps=5)
    )

study.optimize(objective, n_trials=100)
df = study.trials_dataframe()
df
df.to_csv(r'C:\Users\19189\Desktop\MD_cat_trial1.csv',index=False)
# Out:
# [I 2024-04-21 11:47:57,392] A new study created in memory with name: catboost_parameter_opt
# [I 2024-04-21 11:55:56,325] Trial 0 finished with value: 0.3696670438408053 and parameters: {'iterations': 700, 'learning_rate': 0.03007414396676305, 'depth': 6, 'l2_leaf_reg': 0.0006242035821544579, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'random_strength': 0.004547337743564287, 'score_function': 'L2', 'rsm': 0.93752479191974, 'bagging_temperature': 6.218668238190835}. Best is trial 0 with value: 0.3696670438408053.
# [I 2024-04-21 12:57:18,716] Trial 1 finished with value: -0.05074410850361546 and parameters: {'iterations': 600, 'learning_rate': 0.00015116762301032596, 'depth': 12, 'l2_leaf_reg': 0.0016595459096589117, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'random_strength': 0.0015839232347978093, 'score_function': 'Cosine', 'rsm': 0.1688054224027743, 'bagging_temperature': 3.2271508881335755}. Best is trial 0 with value: 0.3696670438408053.
# [I 2024-04-21 12:59:21,840] Trial 2 finished with value: -0.08206435617337524 and parameters: {'iterations': 600, 'learning_rate': 0.00017554548155843106, 'depth': 4, 'l2_leaf_reg': 0.07643419628454186, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'random_strength': 0.13807604724914085, 'score_function': 'L2', 'rsm': 0.4677126788141665, 'bagging_temperature': 5.4548720266723585}. Best is trial 0 with value: 0.3696670438408053.
# [I 2024-04-21 13:00:26,317] Trial 3 finished with value: -0.012128526115416104 and parameters: {'iterations': 700, 'learning_rate': 0.0004109243260739062, 'depth': 4, 'l2_leaf_reg': 0.00011867139855850612, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'random_strength': 2.2237493781829506e-05, 'score_function': 'Cosine', 'rsm': 0.17286022899178355}. Best is trial 0 with value: 0.3696670438408053.
# [I 2024-04-21 13:07:37,564] Trial 4 finished with value: 0.3176863671961165 and parameters: {'iterations': 500, 'learning_rate': 0.012928480721442644, 'depth': 4, 'l2_leaf_reg': 1.1344508929080276e-06, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'random_strength': 3.031064580513711e-06, 'score_function': 'Cosine', 'rsm': 0.6037601638087909, 'subsample': 0.7590391617263942}. Best is trial 0 with value: 0.3696670438408053.
# [I 2024-04-21 13:17:03,858] Trial 5 finished with value: 0.06017344411679448 and parameters: {'iterations': 600, 'learning_rate': 0.0010730336229948436, 'depth': 4, 'l2_leaf_reg': 3.539535186992949e-05, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'random_strength': 0.06756074056015327, 'score_function': 'Cosine', 'rsm': 0.6258033205841081, 'bagging_temperature': 1.2740651610765352}. Best is trial 0 with value: 0.3696670438408053.
# [I 2024-04-21 13:18:23,008] Trial 6 finished with value: 0.17769972164549347 and parameters: {'iterations': 600, 'learning_rate': 0.0044699619992991275, 'depth': 4, 'l2_leaf_reg': 2.4090714546491728e-06, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'random_strength': 0.1786958110538721, 'score_function': 'Cosine', 'rsm': 0.265695298024709, 'bagging_temperature': 2.382034901761656}. Best is trial 0 with value: 0.3696670438408053.
# [I 2024-04-21 13:25:39,971] Trial 7 finished with value: 0.07194185825541696 and parameters: {'iterations': 700, 'learning_rate': 0.0024057636204189658, 'depth': 6, 'l2_leaf_reg': 1.1243895154581565e-06, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'random_strength': 0.016238026947726553, 'score_function': 'L2', 'rsm': 0.6851683006439, 'bagging_temperature': 9.568749186504371}. Best is trial 0 with value: 0.3696670438408053.
# [I 2024-04-21 15:30:50,341] Trial 8 finished with value: 0.5023379036238316 and parameters: {'iterations': 700, 'learning_rate': 0.009811293815475053, 'depth': 12, 'l2_leaf_reg': 0.792909776135083, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'random_strength': 0.002418436435627156, 'score_function': 'Cosine', 'rsm': 0.30245901502142725}. Best is trial 8 with value: 0.5023379036238316.
# [I 2024-04-22 02:09:04,195] Trial 9 finished with value: -0.04586118337707083 and parameters: {'iterations': 900, 'learning_rate': 0.00035627807819366044, 'depth': 12, 'l2_leaf_reg': 1.2001742489373431e-05, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'random_strength': 1.2546954196000627e-06, 'score_function': 'Cosine', 'rsm': 0.1707261875127009, 'bagging_temperature': 7.980593915504647}. Best is trial 8 with value: 0.5023379036238316.
# [I 2024-04-22 07:10:55,445] Trial 10 finished with value: 0.5537058893073425 and parameters: {'iterations': 1000, 'learning_rate': 0.05195087349854926, 'depth': 10, 'l2_leaf_reg': 0.8124329970418442, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'random_strength': 0.00015070897262938095, 'score_function': 'L2', 'rsm': 0.3037411535337428}. Best is trial 10 with value: 0.5537058893073425.
# [I 2024-04-22 13:06:50,745] Trial 11 finished with value: 0.5451303560365753 and parameters: {'iterations': 1000, 'learning_rate': 0.07804970309293051, 'depth': 10, 'l2_leaf_reg': 0.9664238252051711, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'random_strength': 0.00015454293870599369, 'score_function': 'L2', 'rsm': 0.35777342737933027}. Best is trial 10 with value: 0.5537058893073425.
# [I 2024-04-22 14:52:26,149] Trial 12 finished with value: 0.5491326671745231 and parameters: {'iterations': 1000, 'learning_rate': 0.08373024477078322, 'depth': 10, 'l2_leaf_reg': 0.6236286014855653, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'random_strength': 0.00010140677873300878, 'score_function': 'L2', 'rsm': 0.10390342764238139}. Best is trial 10 with value: 0.5537058893073425.
# [I 2024-04-22 16:41:21,554] Trial 13 finished with value: 0.5392910012583072 and parameters: {'iterations': 1000, 'learning_rate': 0.09264382956668554, 'depth': 10, 'l2_leaf_reg': 0.03132297257654014, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'random_strength': 4.486532596381564, 'score_function': 'L2', 'rsm': 0.10681757877374391}. Best is trial 10 with value: 0.5537058893073425.
# [I 2024-04-22 18:21:48,688] Trial 14 finished with value: 0.5437075492288752 and parameters: {'iterations': 900, 'learning_rate': 0.030082246520498238, 'depth': 10, 'l2_leaf_reg': 0.06615546542120729, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'random_strength': 0.00016357348728203035, 'score_function': 'L2', 'rsm': 0.10974944748327291}. Best is trial 10 with value: 0.5537058893073425.
# [I 2024-04-22 19:10:55,489] Trial 15 finished with value: 0.4735651505422915 and parameters: {'iterations': 900, 'learning_rate': 0.0379325088180816, 'depth': 8, 'l2_leaf_reg': 0.005930931216597215, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'random_strength': 0.0002093533729057713, 'score_function': 'L2', 'rsm': 0.21523341068024546, 'subsample': 0.1141147607683271}. Best is trial 10 with value: 0.5537058893073425.
# [I 2024-04-22 19:48:49,362] Trial 16 finished with value: 0.4847454820439854 and parameters: {'iterations': 1000, 'learning_rate': 0.01178386514258315, 'depth': 8, 'l2_leaf_reg': 0.16882478240832047, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'random_strength': 2.4612279983936054e-05, 'score_function': 'L2', 'rsm': 0.13873189645199321}. Best is trial 10 with value: 0.5537058893073425.
# [I 2024-04-23 01:44:18,076] Trial 17 finished with value: 0.5460947874733125 and parameters: {'iterations': 800, 'learning_rate': 0.04614036978246081, 'depth': 10, 'l2_leaf_reg': 0.01104297623377124, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'random_strength': 1.4496538867753626e-05, 'score_function': 'L2', 'rsm': 0.45104601115268617}. Best is trial 10 with value: 0.5537058893073425.
# [I 2024-04-23 02:32:48,847] Trial 18 finished with value: 0.3990827177002989 and parameters: {'iterations': 800, 'learning_rate': 0.0053308875384030395, 'depth': 8, 'l2_leaf_reg': 0.30412875258659783, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'random_strength': 0.0005263458041197944, 'score_function': 'L2', 'rsm': 0.22523202076174775}. Best is trial 10 with value: 0.5537058893073425.
# [I 2024-04-23 08:04:16,205] Trial 19 finished with value: 0.4899821336205738 and parameters: {'iterations': 900, 'learning_rate': 0.017171746457727892, 'depth': 10, 'l2_leaf_reg': 0.016153553915585275, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'random_strength': 7.17557600451296e-06, 'score_function': 'L2', 'rsm': 0.37989520004231303, 'subsample': 0.2902516479687983}. Best is trial 10 with value: 0.5537058893073425.
# [I 2024-04-23 08:16:16,212] Trial 20 finished with value: 0.218029994267046 and parameters: {'iterations': 1000, 'learning_rate': 0.0014953044881215786, 'depth': 6, 'l2_leaf_reg': 0.0015924010167742179, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'random_strength': 6.434985001941342e-05, 'score_function': 'L2', 'rsm': 0.1345736342263635}. Best is trial 10 with value: 0.5537058893073425.
# [I 2024-04-23 14:40:25,869] Trial 21 finished with value: 0.5504472733745953 and parameters: {'iterations': 800, 'learning_rate': 0.04716839628350728, 'depth': 10, 'l2_leaf_reg': 0.2664354806499556, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'random_strength': 1.1861620810716055e-05, 'score_function': 'L2', 'rsm': 0.4880186181056681}. Best is trial 10 with value: 0.5537058893073425.
